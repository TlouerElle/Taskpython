# %%
import sklearn
from sklearn import datasets,tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score, recall_score,classification_report
import matplotlib.pyplot as plt

# %%
iris_data = datasets.load_iris()
x_train,x_test,y_train,y_test = train_test_split(iris_data.data,iris_data.target,test_size = 0.30,random_state = 20)
# x_train    划分出的训练集数据（返回值）
# x_test    划分出的测试集数据（返回值）
# y_train    划分出的训练集标签（返回值）
# y_test    划分出的测试集标签（返回值
#花萼长度、花萼宽度、花瓣长度、花瓣宽度（花萼宽度、花瓣长度）

#目标属性 三种类别山鸢尾花、杂色鸢尾花、维吉尼亚鸢尾花
label_list = ['mountainIris', 'variegatedIris', 'virginiaIris']

# %%
#'gini'对应CART算法，'entropy'对应ID3算法
dt_model = tree.DecisionTreeClassifier(criterion='gini', min_samples_leaf=3)
dt_model.fit(x_train, y_train)
# %matplotlib inline
fig=plt.figure(figsize=(10,10))
tree.plot_tree(dt_model,filled="True",feature_names=["Sepal length","Sepal width","Petal length","Petal width"],class_names=['mountainIris', 'variegatedIris', 'virginiaIris'])
# Out:
# [Text(186.0, 475.65000000000003, 'Petal width <= 0.8\ngini = 0.665\nsamples = 105\nvalue = [37, 32, 36]\nclass = mountainIris'),
#  Text(93.0, 339.75, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = mountainIris'),
#  Text(279.0, 339.75, 'Petal width <= 1.75\ngini = 0.498\nsamples = 68\nvalue = [0, 32, 36]\nclass = virginiaIris'),
#  Text(186.0, 203.85000000000002, 'gini = 0.0\nsamples = 31\nvalue = [0, 31, 0]\nclass = variegatedIris'),
#  Text(372.0, 203.85000000000002, 'Petal length <= 4.85\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = virginiaIris'),
#  Text(279.0, 67.94999999999999, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginiaIris'),
#  Text(465.0, 67.94999999999999, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = virginiaIris')]

# %%
y_train_hat = dt_model.predict(x_train)
print('accuracy score : ',end = '')
print(accuracy_score(y_train, y_train_hat))
print('precision score : ',end = '')
print(precision_score(y_train, y_train_hat,average='macro'))
print('recall score : ',end = '')
print(recall_score(y_train, y_train_hat,average='macro'))
target_names = ['mountainIris', 'variegatedIris', 'virginiaIris']
print(classification_report(y_train, y_train_hat,target_names=target_names))
# Out:
# accuracy score : 0.9904761904761905
# precision score : 0.990990990990991
# recall score : 0.9895833333333334
#                 precision    recall  f1-score   support
#
#   mountainIris       1.00      1.00      1.00        37
# variegatedIris       1.00      0.97      0.98        32
#   virginiaIris       0.97      1.00      0.99        36
#
#       accuracy                           0.99       105
#      macro avg       0.99      0.99      0.99       105
#   weighted avg       0.99      0.99      0.99       105

# %%
y_test_hat = dt_model.predict(x_test)
print('accuracy score : ',end = '')
print(accuracy_score(y_test, y_test_hat))
print('precision score : ',end = '')
print(precision_score(y_test, y_test_hat,average='macro'))
print('recall score : ',end = '')
print(recall_score(y_test, y_test_hat,average='macro'))
target_names = ['mountainIris', 'variegatedIris', 'virginiaIris']
print(classification_report(y_test, y_test_hat))
# Out:
# accuracy score : 0.8888888888888888
# precision score : 0.927536231884058
# recall score : 0.8809523809523809
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.78      1.00      0.88        18
#            2       1.00      0.64      0.78        14
#
#     accuracy                           0.89        45
#    macro avg       0.93      0.88      0.89        45
# weighted avg       0.91      0.89      0.88        45
