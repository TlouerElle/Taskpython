# %%
from pyecharts.charts import Pie,Funnel,Timeline
from pyecharts import options as opts
from pyecharts.globals import ThemeType
import json
import pandas as pd

# %%
with open('shoesV2.json','r',encoding='utf-8-sig') as file:
    data = json.load(file)
data = pd.json_normalize(data)
data.sales = data.sales.apply(lambda x:x.split('人付款')[0]).astype(int)
data.dropna(subset=['info.款式'],inplace=True)
top4Shop = data[['nick','sales']].groupby(by=['nick'],sort=False).sum().sort_values(by=['sales'],ascending=False).index[0:4].tolist()
shop0 = data[data.nick == top4Shop[0]][['sales','info.款式']].groupby(by=['info.款式']).sum()
shop1 = data[data.nick == top4Shop[1]][['sales','info.款式']].groupby(by=['info.款式']).sum()
shop2 = data[data.nick == top4Shop[2]][['sales','info.款式']].groupby(by=['info.款式']).sum()
shop3 = data[data.nick == top4Shop[3]][['sales','info.款式']].groupby(by=['info.款式']).sum()
top4 = pd.merge(shop0,shop1,on='info.款式',how='outer')
top4 = pd.merge(top4,shop2,on='info.款式',how='outer')
top4 = pd.merge(top4,shop3,on='info.款式',how='outer')
top4.columns = top4Shop
top4 = top4.fillna(0)
print(top4)
# Out:
#            意尔康皮鞋旗舰店  意尔康男鞋旗舰店  乙方乙方88888  意尔康品牌店
# info.款式
# 乐福鞋            50.0       7.0        0.0     0.0
# 伐木鞋            12.0       0.0        0.0     0.0
# 休闲皮鞋         3192.0     751.0      348.0   119.0
# 休闲高帮皮鞋         27.0       7.0        0.0     0.0
# 商务休闲鞋        4774.0    1010.0      195.0   177.0
# 布洛克鞋           27.0       8.0        0.0     0.0
# 德比鞋（正装皮鞋）    3959.0     538.0        0.0    90.0
# 懒人鞋            32.0      47.0        0.0     0.0
# 户外休闲鞋         157.0     135.0        0.0    54.0
# 板鞋            107.0     101.0        0.0     3.0
# 沙滩鞋           638.0       0.0        0.0    54.0
# 豆豆鞋           505.0      16.0        0.0     0.0
# 运动休闲鞋         175.0      50.0        0.0     1.0
# 镂空皮鞋          144.0       0.0        0.0     0.0
# 高帮板鞋           25.0       0.0        0.0     0.0
# 布鞋              0.0       5.0        0.0     0.0
# 户外靴             0.0       0.0        0.0     0.0
# 正装高帮皮鞋          0.0       0.0        0.0     0.0

# %%
pie = Pie()
pie.add('',[list(z) for z in zip(top4Shop,top4[2:3].values.tolist()[0])])
pie.set_global_opts(title_opts=opts.TitleOpts(title='排名前4男鞋里休闲皮鞋的销售情况'),legend_opts=opts.LegendOpts(type_="scroll", pos_left="right", orient="vertical"))

# %%
funnel = Funnel()
funnel.add('',[list(z) for z in zip(top4Shop,top4[2:3].values.tolist()[0])])
funnel.set_global_opts(title_opts=opts.TitleOpts(title='排名前4男鞋里休闲皮鞋的销售情况'))

# %%
timeline = Timeline(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
timeline.add(pie,'排名前4休闲皮鞋销售饼图')
timeline.add(funnel,'排名前4休闲皮鞋销漏斗图')
timeline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="396571c126ec424fa4484a7f7fbe5720" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_396571c126ec424fa4484a7f7fbe5720 = echarts.init(
#                     document.getElementById('396571c126ec424fa4484a7f7fbe5720'), 'light', {renderer: 'canvas'});
#                 var option_396571c126ec424fa4484a7f7fbe5720 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "funnel",
#                 "data": [
#                     {
#                         "name": "\u610f\u5c14\u5eb7\u76ae\u978b\u65d7\u8230\u5e97",
#                         "value": 3192.0
#                     },
#                     {
#                         "name": "\u610f\u5c14\u5eb7\u7537\u978b\u65d7\u8230\u5e97",
#                         "value": 751.0
#                     },
#                     {
#                         "name": "\u4e59\u65b9\u4e59\u65b988888",
#                         "value": 348.0
#                     },
#                     {
#                         "name": "\u610f\u5c14\u5eb7\u54c1\u724c\u5e97",
#                         "value": 119.0
#                     }
#                 ],
#                 "sort": "descending",
#                 "gap": 0,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "\u6392\u540d\u524d4\u4f11\u95f2\u76ae\u978b\u9500\u552e\u997c\u56fe",
#                 "\u6392\u540d\u524d4\u4f11\u95f2\u76ae\u978b\u9500\u6f0f\u6597\u56fe"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u610f\u5c14\u5eb7\u76ae\u978b\u65d7\u8230\u5e97",
#                         "\u610f\u5c14\u5eb7\u7537\u978b\u65d7\u8230\u5e97",
#                         "\u4e59\u65b9\u4e59\u65b988888",
#                         "\u610f\u5c14\u5eb7\u54c1\u724c\u5e97"
#                     ],
#                     "selected": {},
#                     "type": "scroll",
#                     "show": true,
#                     "left": "right",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\u610f\u5c14\u5eb7\u76ae\u978b\u65d7\u8230\u5e97",
#                             "value": 3192.0
#                         },
#                         {
#                             "name": "\u610f\u5c14\u5eb7\u7537\u978b\u65d7\u8230\u5e97",
#                             "value": 751.0
#                         },
#                         {
#                             "name": "\u4e59\u65b9\u4e59\u65b988888",
#                             "value": 348.0
#                         },
#                         {
#                             "name": "\u610f\u5c14\u5eb7\u54c1\u724c\u5e97",
#                             "value": 119.0
#                         }
#                     ],
#                     "radius": [
#                         "0%",
#                         "75%"
#                     ],
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u6392\u540d\u524d4\u7537\u978b\u91cc\u4f11\u95f2\u76ae\u978b\u7684\u9500\u552e\u60c5\u51b5",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u4e59\u65b9\u4e59\u65b988888",
#                         "\u610f\u5c14\u5eb7\u7537\u978b\u65d7\u8230\u5e97",
#                         "\u610f\u5c14\u5eb7\u54c1\u724c\u5e97",
#                         "\u610f\u5c14\u5eb7\u76ae\u978b\u65d7\u8230\u5e97"
#                     ],
#                     "selected": {
#                         "\u610f\u5c14\u5eb7\u76ae\u978b\u65d7\u8230\u5e97": true,
#                         "\u610f\u5c14\u5eb7\u7537\u978b\u65d7\u8230\u5e97": true,
#                         "\u4e59\u65b9\u4e59\u65b988888": true,
#                         "\u610f\u5c14\u5eb7\u54c1\u724c\u5e97": true
#                     }
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "funnel",
#                     "data": [
#                         {
#                             "name": "\u610f\u5c14\u5eb7\u76ae\u978b\u65d7\u8230\u5e97",
#                             "value": 3192.0
#                         },
#                         {
#                             "name": "\u610f\u5c14\u5eb7\u7537\u978b\u65d7\u8230\u5e97",
#                             "value": 751.0
#                         },
#                         {
#                             "name": "\u4e59\u65b9\u4e59\u65b988888",
#                             "value": 348.0
#                         },
#                         {
#                             "name": "\u610f\u5c14\u5eb7\u54c1\u724c\u5e97",
#                             "value": 119.0
#                         }
#                     ],
#                     "sort": "descending",
#                     "gap": 0,
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
